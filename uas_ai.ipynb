# %%
import re
import pandas as pd

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/My Drive/newdf.csv')
df.head()
# Out:
#    Unnamed: 0  JobID  WindowID                             Title  \
# 0           0      1         1  Security Engineer/Technical Lead
# 1           1      4         1         SAP Business Analyst / WM
# 2           2      7         1     P/T HUMAN RESOURCES ASSISTANT
# 3           3      8         1            Route Delivery Drivers
# 4           4      9         1                      Housekeeping
#
#                                          Description  \
# 0  <p>Security Clearance Required:&nbsp; Top Secr...
# 1  <strong>NO Corp. to Corp resumes&nbsp;are bein...
# 2  <b>    <b> P/T HUMAN RESOURCES ASSISTANT</b> <...
# 3  CITY BEVERAGES Come to work for the best in th...
# 4  I make  sure every part of their day is magica...
#
#                                         Requirements         City State  \
# 0  <p>SKILL SET</p>\r<p>&nbsp;</p>\r<p>Network Se...   Washington    DC
# 1  <p><b>WHAT YOU NEED: </b></p>\r<p>Four year co...    Charlotte    NC
# 2  Please refer to the Job Description to view th...  Winter Park    FL
# 3  Please refer to the Job Description to view th...      Orlando    FL
# 4  Please refer to the Job Description to view th...      Orlando    FL
#
#   Country     Zip5 StartDate          EndDate
# 0      US  20531.0   17:01.6   4/6/2012 23:59
# 1      US  28217.0   03:44.1  4/20/2012 23:59
# 2      US  32792.0   36:55.4   4/1/2012 23:59
# 3      US      NaN   01:10.1   4/2/2012 23:59
# 4      US      NaN   01:11.9   4/2/2012 23:59

# %%
def remove_stop_words(text):
    stop_words = set(stopwords.words('english'))
    tokens = word_tokenize(text)
    filtered = [word for word in tokens if word not in stop_words]
    return ' '.join(filtered)

# %%
def stem_words(text):
    porter = PorterStemmer()
    token_words = word_tokenize(text)
    stem_sentence = []
    for word in token_words:
        stem_sentence.append(porter.stem(word))
        stem_sentence.append(" ")
    return "".join(stem_sentence)

# %%
def lemmatize_words(text):
    lemmatizer = WordNetLemmatizer()
    token_words = word_tokenize(text)
    lemma_sentence = []
    for word in token_words:
        lemma_sentence.append(lemmatizer.lemmatize(word))
        lemma_sentence.append(" ")
    return "".join(lemma_sentence)

# %%
def remove_unnesessary_symbols(df):
    removePattern = r'(<(.*?)>)|(&\w+)'
    addSpacePattern = r'([;:])|(\\r)|(\\n)'
    removeExtraSpaces = r'(\s\s+?)(?=\S)'
    df['DescCleaned'] = df['Description'].str.lower()
    df['DescCleaned'] = df['DescCleaned'].str.replace(removePattern, "")
    df['DescCleaned'] = df['DescCleaned'].str.replace(addSpacePattern, " ")
    df['DescCleaned'] = df['DescCleaned'].str.replace(removeExtraSpaces, " ")
    # Same for Requirements
    df['ReqCleaned'] = df['Requirements'].str.lower()
    df['ReqCleaned'] = df['ReqCleaned'].str.replace(removePattern, "")
    df['ReqCleaned'] = df['ReqCleaned'].str.replace(addSpacePattern, " ")
    df['ReqCleaned'] = df['ReqCleaned'].str.replace(removeExtraSpaces, " ")

    # Normalize Text
    df['DescCleaned'] = df['DescCleaned'].apply(remove_stop_words)
    df['DescCleaned'] = df['DescCleaned'].apply(stem_words)
    df['DescCleaned'] = df['DescCleaned'].apply(lemmatize_words)

    df['ReqCleaned'] = df['ReqCleaned'].apply(remove_stop_words)
    df['ReqCleaned'] = df['ReqCleaned'].apply(stem_words)
    df['ReqCleaned'] = df['ReqCleaned'].apply(lemmatize_words)

    return df

# %%
def search_job(df, keywords):
    results = []
    for index, row in df.iterrows():
        if any(keyword in str(row[column]).lower() for column in ['Title', 'DescCleaned', 'ReqCleaned', 'Country'] for keyword in keywords):
            results.append(row['Title'])
    if len(results) == 0:
        return "Tidak ditemukan hasil yang cocok dengan kata kunci yang diberikan."
    else:
        return "Berikut hasil pencarian yang cocok dengan kata kunci '{}':\n{}".format(', '.join(keywords), '\n- '.join(results))

# %%
df_copy = df.copy()
useless_col = ['Unnamed: 0', 'JobID', 'WindowID', 'StartDate', 'EndDate', 'Zip5', 'State']
df_copy = df_copy.drop(useless_col, axis = 1)
df_copy = df_copy.dropna()
df_copy.head()
# Out:
#                               Title  \
# 0  Security Engineer/Technical Lead
# 1         SAP Business Analyst / WM
# 2     P/T HUMAN RESOURCES ASSISTANT
# 3            Route Delivery Drivers
# 4                      Housekeeping
#
#                                          Description  \
# 0  <p>Security Clearance Required:&nbsp; Top Secr...
# 1  <strong>NO Corp. to Corp resumes&nbsp;are bein...
# 2  <b>    <b> P/T HUMAN RESOURCES ASSISTANT</b> <...
# 3  CITY BEVERAGES Come to work for the best in th...
# 4  I make  sure every part of their day is magica...
#
#                                         Requirements         City Country
# 0  <p>SKILL SET</p>\r<p>&nbsp;</p>\r<p>Network Se...   Washington      US
# 1  <p><b>WHAT YOU NEED: </b></p>\r<p>Four year co...    Charlotte      US
# 2  Please refer to the Job Description to view th...  Winter Park      US
# 3  Please refer to the Job Description to view th...      Orlando      US
# 4  Please refer to the Job Description to view th...      Orlando      US

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 997 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         997 non-null    object
#  1   Description   997 non-null    object
#  2   Requirements  997 non-null    object
#  3   City          997 non-null    object
#  4   Country       997 non-null    object
# dtypes: object(5)
# memory usage: 46.7+ KB

# %%
df_copy = remove_unnesessary_symbols(df_copy)
df_copy.head()
# Out:
# <ipython-input-37-4ad9efc8e307>:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['DescCleaned'] = df['DescCleaned'].str.replace(removePattern, "")
# <ipython-input-37-4ad9efc8e307>:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['DescCleaned'] = df['DescCleaned'].str.replace(addSpacePattern, " ")
# <ipython-input-37-4ad9efc8e307>:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['DescCleaned'] = df['DescCleaned'].str.replace(removeExtraSpaces, " ")
# <ipython-input-37-4ad9efc8e307>:11: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['ReqCleaned'] = df['ReqCleaned'].str.replace(removePattern, "")
# <ipython-input-37-4ad9efc8e307>:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['ReqCleaned'] = df['ReqCleaned'].str.replace(addSpacePattern, " ")
# <ipython-input-37-4ad9efc8e307>:13: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['ReqCleaned'] = df['ReqCleaned'].str.replace(removeExtraSpaces, " ")
#                               Title  \
# 0  Security Engineer/Technical Lead
# 1         SAP Business Analyst / WM
# 2     P/T HUMAN RESOURCES ASSISTANT
# 3            Route Delivery Drivers
# 4                      Housekeeping
#
#                                          Description  \
# 0  <p>Security Clearance Required:&nbsp; Top Secr...
# 1  <strong>NO Corp. to Corp resumes&nbsp;are bein...
# 2  <b>    <b> P/T HUMAN RESOURCES ASSISTANT</b> <...
# 3  CITY BEVERAGES Come to work for the best in th...
# 4  I make  sure every part of their day is magica...
#
#                                         Requirements         City Country  \
# 0  <p>SKILL SET</p>\r<p>&nbsp;</p>\r<p>Network Se...   Washington      US
# 1  <p><b>WHAT YOU NEED: </b></p>\r<p>Four year co...    Charlotte      US
# 2  Please refer to the Job Description to view th...  Winter Park      US
# 3  Please refer to the Job Description to view th...      Orlando      US
# 4  Please refer to the Job Description to view th...      Orlando      US
#
#                                          DescCleaned  \
# 0  secur clearanc requir top secret job number tm...
# 1  corp. corp resum consid direct hire `` perman ...
# 2  p/t human resourc assist —— 1-2 year experi hr...
# 3  citi beverag come work best busi ! citi bevera...
# 4  make sure everi part day magic . disney . drea...
#
#                                           ReqCleaned
# 0  skill set network secur tool webdefend web app...
# 1  need four year colleg degre minimum 5 8+ year ...
# 2           plea refer job descript view requir job
# 3           plea refer job descript view requir job
# 4           plea refer job descript view requir job

# %%
df_copy.loc[0].DescCleaned
# Out:
# 'secur clearanc requir top secret job number tmr-447 locat job washington , dc tmr , inc. equal employ opportun compani job opportun tmr , visit websit www.tmrhq.com send resum hr @ tmrhq2.com job summari lead custom overal cyber secur strategi , formal servic offer consist itil best practic , provid design architectur support . provid secur design / architectur support ojp secur divis ( itsd ) lead secop team day day ojp secur oper support provid direct need secur incid technic issu work concert network oper design /integr best secur postur support busi develop function includ captur manag , propos develop respons , initi includ confer , trade show , webinar , develop white paper like . identifi resourc mentor in-hous talent ensur tmr remain respons grow initi contract qualifi personnel . '

# %%
keywords = input("Masukkan kata kunci: ")
keywords = stem_words(keywords)
keywords = lemmatize_words(keywords)
keywords = keywords.split()


search_results = search_job(df_copy, keywords)
print(search_results)
# Out:
# Masukkan kata kunci: software engineer
# Berikut hasil pencarian yang cocok dengan kata kunci 'softwar, engin':
# Security Engineer/Technical Lead
# - ELECTRONIC PRE-PRESS PROFESSIONAL
# - CONSTRUCTION PROJECT MGR & PM TRAINEE
# - Financial Planner/ParaPlanner
# - CIVIL ENGINEER
# - MECHANICAL/INDUSTRIAL ENGINEER
# - COMPUTER PROFESSIONALS
# - CIVIL ENGINEER
# - TECH SUPPORT REPRESENTATIVE
# - MACHINE SHOP
# - BUSINESS ANALYST
# - FINANCIAL ACCOUNTANT
# - Electronics Repair Technician
# - ENGINEER III WATER/WASTEWATER AECOM Technical Services
# - Software Engineer
# - DATABASE ADMINISTRATOR II
# - Process Lab Coordinator
# - Business Development
# - Manufacturing
# - Product Dvlpmnt Eng Team Lead
# - Engineer
# - Project Engineering
# - System Analyst
# - Supervisor of Instruction High School
# - METAL FABRICATION MACHINISTS & WELDER-FITTERS
# - IT Administrator
# - Quality Assurance Specialist
# - Civil Engineer
# - Engineer/Designer/CADD
# - MANUFACTURING
# - CONSTRUCTION POSITIONS
# - SR. SOFTWARE ENGINEER
# - IT POSITIONS
# - ENGINEER
# - DRAFTER
# - IT Recruiter
# - Tool Engineer - Injection Molding
# - Practice Manager Opportunity
# - Software Architect
# - SQL DBA
# - Regional Sales Manager
# - National Account Manager
# - Director, Enterprise Network Architecture
# - Client Engineer I - Network Operations Center
# - Associate Intrado Technical Support Specialist
# - Systems Administrator
# - Quality Assurance Support Analyst
# - Senior IP Engineer
# - Account Management Specialist
# - Underwriting Assistant
# - Software Tester
# - Embedded Systems Software Engineer
# - Customer Service Representative
# - Equipment Maintenance Technician III
# - Equipment Maintenance Technician III
# - Associate Engineer
# - Software Engineer - BIOS (Basic Input/Output System)
# - Senior Test Engineer
# - Test Engineering Manager
# - Automation Engineer - Manufacturing
# - Quality Assurance Manager
# - Cloverleaf HL7 Interface Analyst
# - Java Developer
# - Medical Sales Rep - Peripehral Vascular Disease Equipment
# - Plastics Engineer - Injection Molding
# - PROJECT ENGINEER - PLASTIC PRODUCT DEVELOPMENT
# - Systems Admin - Mid level
# - Lead Buyer Automotive
# - Unigraphics CAD Designer
# - National Sales & Marketing Manager
# - Facilities Engineer
# - Test Engineer
# - Embedded Software Engineer
# - Associate Mechanical Engineer
# - Financial Modeler - Treasury / Banking / Evaluation
# - Product Test Engineer II
# - Electrical Engineer
# - Controls Engineer
# - Construction -  Electrical - project management
# - Director of Product Development
# - User Experience Specialist UX/UI Advance to Management
# - Field Service Engineer-Medical Software System
# - Field Service Engineer - Medical Software System
# - Field Service Engineer-Medical Software System
# - Network Engineer / PACS
# - Airworthiness Inspector
# - Aircraft Avionics Installer I
# - Documentation Management Specialist
# - Process Engineer
# - Project Engineer
# - Plumbing Design Engineer
# - Senior Manufacturing Engineer - Mechanical Assembly
# - Corporate Lean Sigma Black Belt - Supply Chain
# - Materials Manager
# - Plating Engineer
# - Quality Engineer
# - Instrumentation & Electrical Technician – 4/4/2012
# - MECHANICAL DESIGN ENGINEER – Electronic Assemblies
# - QUALITY MANAGER –  Growing and Stable Company!
# - MECHANICAL ENGINEER – Food / Beverage Manufacturer
# - Pulp & Paper Industry Jobs - Engineering To Managment to Hourly
# - Regional Controller - Finance Manager - Growing Manufacturer
# - Maintenance Supervisor – Beverage- Growth Potential.
# - Maintenance Technician – Stable and Growing Manufacturer
# - Pulp & Paper Industry Jobs
# - Network and Application Performance Engineers
# - Vice President, Business Development, New York, NY:
# - SOUTH NASSAU COMMUNITIES HOSPITARNs, Emergency Department FT , P
# - MANUFACTURING Ellanef Manufacturing Corp
# - ITT EXELITHE POWER OF INGENUITYOur North Amityville facility
# - Administrative Asst - Part Time
# - Sr. Software Architect
# - Engineer Water Treatment
# - Senior Sales Engineer
# - Engineering - Manager Engineering
# - SENIOR SYSTEMS SOFTWARE ENGINEER
# - SOFTWARE QUALITY ASSURANCE ENGINEER- EMBEDDED
# - Programmer Analyst II
# - Sr Director of Business Development, HID Connect – The Americas
# - Senior Software Engineer.
# - INSTRUMENT
# - Project Engineer
# - ENGINEERING OPPORTUNITIES
# - Compliance Manager - Agency - Gerber Life Insurance Company
