# %%
import pandas as pd
import numpy as np
import os
import re
import string

path = os.getcwd()

# %%
def html_tag_remover(text):
    re_html = re.compile('<.*?>')
    new_text = re.sub(re_html, '', text)
    remove_url(new_text)
    return new_text

def remove_url(text):
    return " ".join(re.sub("([^0-9A-Za-z \t])|(\w+:\/\/\S+)", "", text).split())

def remove_punc(text):
    result = input_str.translate(string.maketrans("",""), string.punctuation)
    return result
# Out:
#   File "C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3344\718261666.py", line 11
#     result = input_str.translate(string.maketrans(“”,””), string.punctuation)
#                                                   ^
# SyntaxError: invalid character '“' (U+201C)

# %%
df = pd.read_csv(os.path.join(path, 'resources', 'newdf.csv'))
df.head()
# Out:
#    Unnamed: 0  JobID  WindowID                             Title  \
# 0           0      1         1  Security Engineer/Technical Lead
# 1           1      4         1         SAP Business Analyst / WM
# 2           2      7         1     P/T HUMAN RESOURCES ASSISTANT
# 3           3      8         1            Route Delivery Drivers
# 4           4      9         1                      Housekeeping
#
#                                          Description  \
# 0  <p>Security Clearance Required:&nbsp; Top Secr...
# 1  <strong>NO Corp. to Corp resumes&nbsp;are bein...
# 2  <b>    <b> P/T HUMAN RESOURCES ASSISTANT</b> <...
# 3  CITY BEVERAGES Come to work for the best in th...
# 4  I make  sure every part of their day is magica...
#
#                                         Requirements         City State  \
# 0  <p>SKILL SET</p>\r<p>&nbsp;</p>\r<p>Network Se...   Washington    DC
# 1  <p><b>WHAT YOU NEED: </b></p>\r<p>Four year co...    Charlotte    NC
# 2  Please refer to the Job Description to view th...  Winter Park    FL
# 3  Please refer to the Job Description to view th...      Orlando    FL
# 4  Please refer to the Job Description to view th...      Orlando    FL
#
#   Country     Zip5 StartDate          EndDate
# 0      US  20531.0   17:01.6   4/6/2012 23:59
# 1      US  28217.0   03:44.1  4/20/2012 23:59
# 2      US  32792.0   36:55.4   4/1/2012 23:59
# 3      US      NaN   01:10.1   4/2/2012 23:59
# 4      US      NaN   01:11.9   4/2/2012 23:59

# %% [markdown]
# ### Data Preprocessing
# #### Menghilangkan Beberapa Kolom TIdak Berguna

# %%
df_copy = df.copy()

useless_col = ['WindowID', 'JobID', 'City', 'State', 'StartDate', 'EndDate', 'Zip5', 'Unnamed: 0']
df_copy = df_copy.drop(useless_col, axis = 1)
df_copy.head()
# Out:
#                               Title  \
# 0  Security Engineer/Technical Lead
# 1         SAP Business Analyst / WM
# 2     P/T HUMAN RESOURCES ASSISTANT
# 3            Route Delivery Drivers
# 4                      Housekeeping
#
#                                          Description  \
# 0  <p>Security Clearance Required:&nbsp; Top Secr...
# 1  <strong>NO Corp. to Corp resumes&nbsp;are bein...
# 2  <b>    <b> P/T HUMAN RESOURCES ASSISTANT</b> <...
# 3  CITY BEVERAGES Come to work for the best in th...
# 4  I make  sure every part of their day is magica...
#
#                                         Requirements Country
# 0  <p>SKILL SET</p>\r<p>&nbsp;</p>\r<p>Network Se...      US
# 1  <p><b>WHAT YOU NEED: </b></p>\r<p>Four year co...      US
# 2  Please refer to the Job Description to view th...      US
# 3  Please refer to the Job Description to view th...      US
# 4  Please refer to the Job Description to view th...      US

# %%
df_copy.Country.value_counts()
# Out:
# US    1000
# Name: Country, dtype: int64

# %%
df_copy.Requirements.isna().value_counts()
# Out:
# False    997
# True       3
# Name: Requirements, dtype: int64

# %%
df_copy = df_copy.dropna()
df_copy = df_copy.drop_duplicates()

# %%
df_copy['Country'] = df_copy.Country.apply(lambda x : 'ID')
df_copy.head()
# Out:
#                               Title  \
# 0  Security Engineer/Technical Lead
# 1         SAP Business Analyst / WM
# 2     P/T HUMAN RESOURCES ASSISTANT
# 3            Route Delivery Drivers
# 4                      Housekeeping
#
#                                          Description  \
# 0  <p>Security Clearance Required:&nbsp; Top Secr...
# 1  <strong>NO Corp. to Corp resumes&nbsp;are bein...
# 2  <b>    <b> P/T HUMAN RESOURCES ASSISTANT</b> <...
# 3  CITY BEVERAGES Come to work for the best in th...
# 4  I make  sure every part of their day is magica...
#
#                                         Requirements Country
# 0  <p>SKILL SET</p>\r<p>&nbsp;</p>\r<p>Network Se...      ID
# 1  <p><b>WHAT YOU NEED: </b></p>\r<p>Four year co...      ID
# 2  Please refer to the Job Description to view th...      ID
# 3  Please refer to the Job Description to view th...      ID
# 4  Please refer to the Job Description to view th...      ID

# %%
df_copy['Description'] = df_copy.Description.apply(lambda x : html_tag_remover(x))
df_copy['Requirements'] = df_copy.Requirements.apply(lambda x : html_tag_remover(x))
df_copy.head()
# Out:
#                               Title  \
# 0  Security Engineer/Technical Lead
# 1         SAP Business Analyst / WM
# 2     P/T HUMAN RESOURCES ASSISTANT
# 3            Route Delivery Drivers
# 4                      Housekeeping
#
#                                          Description  \
# 0  Security Clearance Required:&nbsp; Top Secret ...
# 1  NO Corp. to Corp resumes&nbsp;are being consid...
# 2       P/T HUMAN RESOURCES ASSISTANT   ——  1-2 y...
# 3  CITY BEVERAGES Come to work for the best in th...
# 4  I make  sure every part of their day is magica...
#
#                                         Requirements Country
# 0  SKILL SET\r&nbsp;\rNetwork Security tools:\r&n...      ID
# 1  WHAT YOU NEED: \rFour year college degree\rMin...      ID
# 2  Please refer to the Job Description to view th...      ID
# 3  Please refer to the Job Description to view th...      ID
# 4  Please refer to the Job Description to view th...      ID
